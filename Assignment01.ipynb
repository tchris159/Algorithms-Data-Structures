# %% [markdown]
# # Assignment 01
# Name:  Christopher Truong
# Class: INST447
# Section:  9AM MWF

# %% [markdown]
# ## EX 01
# (20pts total)
#
# Find 2 datasets that when combined answer a question that could not be answered by a single dataset alone. This is similar to Worksheet 03 where we wanted to know if ride counts were impacted by the weather.
#
# You can use any data source with the exception of datasets from Kaggle, Capital Area Bikeshare, or any file I have provided you. I recommend checking the following out, but there are many options.
#
# * https://data.gov
# * https://data.gov.uk
# * https://data.gov.ca
# * https://open.canada.ca/en
# * https://data.europa.eu/euodp/en/data/
#
# I would recommend keeping things relatively constrained. If you find that your desired file is gigantic, I have found that many of the data portals will allow you to filter your download.
#
# Download the files and save them in the folder named "data" that is in the same folder as this file.
#
# Please provide a link to where you found these files (the landing page for each file):
# (5pts each file)

# %% [markdown]
# 1)  https://figshare.com/articles/temperature_csv/3171766
# 2)  https://datahub.io/core/sea-level-rise#data

# %% [markdown]
# Tell me what question you intend to answer with these data: (10pts)

# %% [markdown]
# How does the trend in Land and Ocean temperatures from around the 1850s until recent relate to the change in the change in Ocean/Sea Levels along with the change in time?

# %%
# Standard Includes
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %% [markdown]
# ## EX02
# (15 pts)
#
# Now open and clean the first data file. All of the data types need to make sense. All columns should be descriptively named. There needs to be an index.

# %%
temp_data = pd.read_csv('temperature.csv')

temp_data.head(10)
# Out:
#    record_id  month  day  year  AverageTemperatureFahr  \
# 0     474376      1    1  1853                     NaN
# 1     474377      2    1  1853                     NaN
# 2     474378      3    1  1853                     NaN
# 3     474379      4    1  1853                     NaN
# 4     474380      5    1  1853                     NaN
# 5     474381      6    1  1853                 51.9062
# 6     474382      7    1  1853                 52.3886
# 7     474383      8    1  1853                 52.8530
# 8     474384      9    1  1853                 52.5776
# 9     474385     10    1  1853                 54.8726
#
#    AverageTemperatureUncertaintyFahr      City country_id      Country  \
# 0                                NaN  Auckland        NEW  New Zealand
# 1                                NaN  Auckland        NEW  New Zealand
# 2                                NaN  Auckland        NEW  New Zealand
# 3                                NaN  Auckland        NEW  New Zealand
# ...

# %% [markdown]
# ## EX03
# (15 pts)
#
# Now open and clean the second data file. All of the data types need to make sense. All columns should be descriptively named. There needs to be an index.

# %%
bio_data = pd.read_csv('sea_level.csv')

# %%
bio_data.head(10)
# Out:
#    Year  CSIRO - Adjusted sea level (inches)  \
# 0  1880                             0.000000
# 1  1881                             0.220472
# 2  1882                            -0.440945
# 3  1883                            -0.232283
# 4  1884                             0.590551
# 5  1885                             0.531496
# 6  1886                             0.437008
# 7  1887                             0.216535
# 8  1888                             0.299213
# 9  1889                             0.362205
#
#    CSIRO - Lower error bound (inches)  CSIRO - Upper error bound (inches)  \
# 0                           -0.952756                            0.952756
# 1                           -0.732283                            1.173228
# 2                           -1.346457                            0.464567
# 3                           -1.129921                            0.665354
# 4                           -0.283465                            1.464567
# ...

# %%
del bio_data['NOAA - Adjusted sea level (inches)']

# %%
bio_data.head(10)
# Out:
#    Year  CSIRO - Adjusted sea level (inches)  \
# 0  1880                             0.000000
# 1  1881                             0.220472
# 2  1882                            -0.440945
# 3  1883                            -0.232283
# 4  1884                             0.590551
# 5  1885                             0.531496
# 6  1886                             0.437008
# 7  1887                             0.216535
# 8  1888                             0.299213
# 9  1889                             0.362205
#
#    CSIRO - Lower error bound (inches)  CSIRO - Upper error bound (inches)
# 0                           -0.952756                            0.952756
# 1                           -0.732283                            1.173228
# 2                           -1.346457                            0.464567
# 3                           -1.129921                            0.665354
# 4                           -0.283465                            1.464567
# ...

# %%
bio_data.columns = [
    'year',
  'CSIRO - Adjusted sea level (inches)',
  'CSIRO - Lower error bound (inches)', 'CSIRO - Upper error bound (inches)'
]
bio_data
# Out:
#      year  CSIRO - Adjusted sea level (inches)  \
# 0    1880                             0.000000
# 1    1881                             0.220472
# 2    1882                            -0.440945
# 3    1883                            -0.232283
# 4    1884                             0.590551
# 5    1885                             0.531496
# 6    1886                             0.437008
# 7    1887                             0.216535
# 8    1888                             0.299213
# 9    1889                             0.362205
# 10   1890                             0.440945
# 11   1891                             0.374016
# 12   1892                             0.500000
# 13   1893                             0.685039
# 14   1894                             0.303150
# 15   1895                             0.767717
# 16   1896                             0.468504
# 17   1897                             0.673228
# 18   1898                             1.043307
# ...

# %% [markdown]
# ## EX04
# (10 pts)
#
# Combine the two files so that I have a clean data set that would allow someone to answer the question you said you were building a dataset for in EX01.

# %%
combined = pd.merge(temp_data, bio_data, on="year")
combined
# Out:
#        record_id  month  day  year  AverageTemperatureFahr  \
# 0         474700      1    1  1880                 65.1560
# 1         474701      2    1  1880                 67.4546
# 2         474702      3    1  1880                 65.8490
# 3         474703      4    1  1880                 62.5262
# 4         474704      5    1  1880                 58.9658
# 5         474705      6    1  1880                 54.1490
# 6         474706      7    1  1880                 53.4470
# 7         474707      8    1  1880                 52.9862
# 8         474708      9    1  1880                 55.6736
# 9         474709     10    1  1880                 56.3720
# 10        474710     11    1  1880                 60.2996
# 11        474711     12    1  1880                 61.8800
# 12       1099635      1    1  1880                 70.7594
# 13       1099636      2    1  1880                 71.0402
# 14       1099637      3    1  1880                 71.7656
# ...

# %%
#Merged on the year so everything aligns

# %%
combined.describe()
len(combined)
# Out:
# 28890

# %% [markdown]
# ## EX05
# (20 pts)
# Nobody likes undocumented data.
# Create the metadata for your DataFrame. Think back to the imports-85.names file from WK04 and the kind of information that it provides. It answers questions like, but not limited to:
# * How many rows are in your DataFrame?
# * How many columns are in your DataFrame?
# * What are the names of the columns?
# * What kind of data are in each column?
# * Is there any missing values? Where and how many?

# %% [markdown]
# #meta data shown below in cell
#
# <meta name="description" content="This dataset is the combination of two interesting subsets which give insights into the relationship between surface temperatures and sea level. " />
# <meta name="keywords" content="Temperature, date, city, data, average, longitude, latitude, adjusted" />
# <meta name="author" content="metatags generator">
# <meta name="robots" content="index, follow">
# <meta name="revisit-after" content="3 month">
# <meta Name="number-of-rows" content="28890 rows">
# <meta Name="Missing-Values?" content="yes">
# <meta Name="columns" content="15 columns">
# <title>Relationship Between Temperature and Sea Level</title>

# %% [markdown]
# ## EX06
# (20 pts)
#
# Explain how your DataFrame (preferably with pretty pictures, but numbers and words are good too) answers your question.

# %%
sns.lmplot(x='year',y='CSIRO - Adjusted sea level (inches)',data=combined,hue='AverageTemperatureUncertaintyFahr', fit_reg=False,
          palette='coolwarm',size=6,aspect=1)

# %% [markdown]
# #For this particular graph I apologize you will have to scroll towards the middle to see the graph.
# #Interestingly enough, this data visualization shows that as time progresses, the temperature increases. This answers my question in that time increases the sea level. yet the majority of the highest average temperatures are generally towards the 1800s and the average surface temperature is decreasing while sea levels are increasing. This is a very interesting answer to the question that has been concluded from these datasets.

# %%
sns.jointplot(x='year',y='CSIRO - Adjusted sea level (inches)',data=combined,kind='kde',color='red')

# %% [markdown]
# According to this visualization, there appears to be a trend where as time goes on, Sea level increases. However also seen in this visualization, the densest portions where temperature is the highes is generally towads the early 1900s. The answer in this particular case from the datasets is stated above. Of course it is always important to be mindful of data sources, fluctuations and variations between data sets, and potential third party lurking factors and variables. Nonetheless it is a very interesting conclusion.
